# %%
import pandas as pd

# %%
data1 = pd.read_csv('Iterations\\Iter1\\data1_done.csv')

# %%
data2 = pd.read_csv('Iterations\\Iter1\\data2_done.csv')

# %%
df = pd.concat([data1, data2], axis=0)

# %%
df
# Out:
#           id                                               text  label  \
# 0          0                                    Bấp bênh vl thế      1
# 1          2  Thấy chán ad page này kiến thức thì nông cản c...      1
# 2          3       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0
# 3          4  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1
# 4          5                                 Má nứng quá aiu ơi      0
# ...      ...                                                ...    ...
# 22999  46002   trong trường hợp này, theo ls. khanh, bà hằng...      1
# 23000  46003   bà cũng không ít lần chỉ trích nặng nề những ...      0
# 23001  46004   “bà nguyễn phương hằng có nhiều biểu hiện đã ...      0
# 23002  46005   vũ đức khanh nói. bà nguyễn phương hằng bắt đ...      0
# 23003  46006  .. trước khi bị bắt, bà nguyễn phương hằng đã ...      0
#
#       dataset_type check
# 0            train  True
# 1            train   NaN
# 2            train   NaN
# ...

# %%
train = df.loc[df['dataset_type'] == 'train']

# %%
val = df.loc[df['dataset_type'] == 'dev']

# %%
test = df.loc[df['dataset_type'] == 'test']

# %%
train
# Out:
#           id                                               text  label  \
# 0          0                                    Bấp bênh vl thế      1
# 1          2  Thấy chán ad page này kiến thức thì nông cản c...      1
# 2          3       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0
# 3          4  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1
# 4          5                                 Má nứng quá aiu ơi      0
# ...      ...                                                ...    ...
# 21126  44119   nhờ vào bàn tay đảm đang, khéo léo cộng thêm ...      0
# 21127  44122   Chính quyền này, nó không phải là cơ quan của...      1
# 21128  44124   Đừng để cho những kẻ độc tài, những kẻ không ...      1
# 21129  44125  ukraine từ chối trung quốc viện trợ trước sự p...      0
# 21130  44133   được bộ chính trị việt nam ban hành vào tháng...      1
#
#       dataset_type check
# 0            train  True
# 1            train   NaN
# 2            train   NaN
# ...

# %%
test
# Out:
#           id                                               text  label  \
# 3333    8407  Từ lúc mấy bro cmt cực kì cl gì đấy là rất khó...      1
# 3334    8408                Nghe trần dần thấy cười đau cả bụng      0
# 3335    8409  Idol tui có khác. Phải v chứ ai như cái con ph...      1
# 3336    8410                          Cảnh Sát GiựT Tiền = CSGT      1
# 3337    8411                     Ông đi đâu mà lạc sang đây đây      0
# ...      ...                                                ...    ...
# 22999  46002   trong trường hợp này, theo ls. khanh, bà hằng...      1
# 23000  46003   bà cũng không ít lần chỉ trích nặng nề những ...      0
# 23001  46004   “bà nguyễn phương hằng có nhiều biểu hiện đã ...      0
# 23002  46005   vũ đức khanh nói. bà nguyễn phương hằng bắt đ...      0
# 23003  46006  .. trước khi bị bắt, bà nguyễn phương hằng đã ...      0
#
#       dataset_type check
# 3333          test   NaN
# 3334          test   NaN
# 3335          test   NaN
# ...

# %%
val
# Out:
#           id                                               text  label  \
# 2396    7470  Cs cha , Cs con , Rận cha, Rận con ...ai đúng ...      1
# 2397    7471                             Long Duy Đào cái tội ớ      0
# 2398    7472                                  Nói gì tào lao kg      1
# 2399    7473                    Chả làm gì cũng có fan cứng =))      0
# 2400    7474  Sao lại cứ đến nụ cười . lên không nghe rõ lời...      0
# ...      ...                                                ...    ...
# 22141  45144   bé trai sơ sinh được phi hành đoàn đặt biệt d...      0
# 22142  45145  cháy xưởng nhựa ở vĩnh phúc trong đêm khoảng 2...      0
# 22143  45146   "đến 2h sáng nay lực lượng chức năng đã dập t...      0
# 22144  45147  dạy trẻ cách xây dựng thực đơn việc lên thực đ...      0
# 22145  45148  câu chuyện thổi nồng độ cồn vẫn luôn gây tranh...      0
#
#       dataset_type check
# 2396           dev   NaN
# 2397           dev   NaN
# 2398           dev   NaN
# ...

# %%
train.to_csv('Iterations\\Iter1\\train.csv', index=False)

# %%
val.to_csv('Iterations\Iter1\\val.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\acer\AppData\Local\Temp\ipykernel_17460\3506965597.py:1: SyntaxWarning: invalid escape sequence '\I'
#   val.to_csv('Iterations\Iter1\\val.csv', index=False)

# %%
test.to_csv('Iterations\Iter1\\test.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\acer\AppData\Local\Temp\ipykernel_17460\1412780607.py:1: SyntaxWarning: invalid escape sequence '\I'
#   test.to_csv('Iterations\Iter1\\test.csv', index=False)
