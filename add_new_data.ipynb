# %%
import pandas as pd

# %%
train_data = pd.read_csv('origin\\train.csv')

# %%
train_data
# Out:
#           id                                               text  label  \
# 0      26180                                    Chuyện ly kỳ..!      0
# 1      11069     Nhìn đội hình chắc ai cũng bt thầy ba yếu nhất      0
# 2      28019                                  Há miệng chờ trê.      0
# 3       4384                       Định mệnh rùi nay là mùng BA      0
# 4      31953  Chính mái tóc ấy mà lớp trưởng ghét tôi. Giờ c...      0
# ...      ...                                                ...    ...
# 33717  44119   nhờ vào bàn tay đảm đang, khéo léo cộng thêm ...      0
# 33718  44122   Chính quyền này, nó không phải là cơ quan của...      1
# 33719  44124   Đừng để cho những kẻ độc tài, những kẻ không ...      1
# 33720  44125  ukraine từ chối trung quốc viện trợ trước sự p...      0
# 33721  44133   được bộ chính trị việt nam ban hành vào tháng...      1
#
#       dataset_type
# 0            train
# 1            train
# 2            train
# 3            train
# ...

# %%
train_data.sort_values(by='id', inplace=True)

# %%
train_data
# Out:
#           id                                               text  label  \
# 16342      0                                    Bấp bênh vl thế      1
# 23003      1  Chắc cũng biết ko tồn tại đc bao lâu nữa nên c...      1
# 22729      2  Thấy chán ad page này kiến thức thì nông cản c...      1
# 9712       3       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0
# 2154       4  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1
# ...      ...                                                ...    ...
# 298    44129  nh cho không ăn được luôn. cảnh báo: video có ...      0
# 17438  44130  dịp hiếm ngắm nhìn chim uyên ương khi du xuân ...      0
# 21211  44131  việt nam: rò rỉ tài liệu đảng cộng sản cảnh bá...      1
# 4611   44132   điều không thay đổi là sự kìm kẹp sắt đá của ...      1
# 33721  44133   được bộ chính trị việt nam ban hành vào tháng...      1
#
#       dataset_type
# 16342        train
# 23003        train
# 22729        train
# 9712         train
# ...

# %%
add_data1 = pd.read_csv('expand_dataset\\viettan-comments_done.csv')

# %%
add_data1
# Out:
#       index                                               text  \
# 0         0          Giờ biết giải thích sao với lão tôn đây 😅
# 1         1  Nguyễn Đức Duẩn Thanh niên nhà Hà Nội thích N ...
# 2         2                            Khỉ bố đang rất đau khổ
# 3         3  Hàng xóm bên cạnh ngta cũng phận nữ nhi mà các...
# 4         4  Sinh nở đã vất vả lắm rồi, đừng hỏi bố đứa trẻ...
# ...     ...                                                ...
# 6693   6693  Khổ nhưng vẫn đc độc lập tự do,được đón lễ lớn...
# 6694   6694         30/4 3 que đu càng tụt quần bay trong gió😂
# 6695   6695                                   ba que khát nước
# 6696   6696        Hoan hô Việt Tân đưa tin rất hay và thời sự
# 6697   6697  Mời các bạn nghe tin chiến thắng chúng tôi mới...
#
#       similarity_proba  predict_proba  average_proba  similarity_label  \
# 0             0.683656       0.876747       0.780202                 1
# ...

# %%
add_data1 = add_data1.loc[add_data1['similarity_label'] == add_data1['predict_label']]

# %%
add_data1
# Out:
#       index                                               text  \
# 0         0          Giờ biết giải thích sao với lão tôn đây 😅
# 2         2                            Khỉ bố đang rất đau khổ
# 3         3  Hàng xóm bên cạnh ngta cũng phận nữ nhi mà các...
# 5         5  Chửa đẻ đã vất vả lắm rồi,đừng hỏi nó là con c...
# 6         6                Khỉ vàng chuồng bên là khỉ cái mà 😆
# ...     ...                                                ...
# 6691   6691  Người việt Nam bị đối sử như người Duy Ngô Nhĩ...
# 6692   6692                                    Top fan\nSáu Đô
# 6694   6694         30/4 3 que đu càng tụt quần bay trong gió😂
# 6696   6696        Hoan hô Việt Tân đưa tin rất hay và thời sự
# 6697   6697  Mời các bạn nghe tin chiến thắng chúng tôi mới...
#
#       similarity_proba  predict_proba  average_proba  similarity_label  \
# 0             0.683656       0.876747       0.780202                 1
# ...

# %%
add_data1.drop(columns=['index'], inplace=True)
add_data1.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\3546024491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data1.drop(columns=['index'], inplace=True)

# %%
add_data1.reset_index(inplace=True, drop= False)

# %%
add_data1.rename(columns={'index': 'id'}, inplace=True)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\396317561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data1.rename(columns={'index': 'id'}, inplace=True)

# %%
start_index = 100000
add_data1['id'] = add_data1['id'] + start_index
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\743258309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data1['id'] = add_data1['id'] + start_index

# %%
add_data1['dataset_type'] = 'train'
add_data1['label'] = add_data1['predict_label']
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\2478583205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data1['dataset_type'] = 'train'
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\2478583205.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data1['label'] = add_data1['predict_label']

# %%
add_data = add_data1[['id', 'text', 'label', 'dataset_type']]

# %%
add_data
# Out:
#           id                                               text  label  \
# 0     100000          Giờ biết giải thích sao với lão tôn đây 😅      1
# 1     100001                            Khỉ bố đang rất đau khổ      0
# 2     100002  Hàng xóm bên cạnh ngta cũng phận nữ nhi mà các...      1
# 3     100003  Chửa đẻ đã vất vả lắm rồi,đừng hỏi nó là con c...      1
# 4     100004                Khỉ vàng chuồng bên là khỉ cái mà 😆      1
# ...      ...                                                ...    ...
# 4074  104074  Người việt Nam bị đối sử như người Duy Ngô Nhĩ...      0
# 4075  104075                                    Top fan\nSáu Đô      0
# 4076  104076         30/4 3 que đu càng tụt quần bay trong gió😂      0
# 4077  104077        Hoan hô Việt Tân đưa tin rất hay và thời sự      0
# 4078  104078  Mời các bạn nghe tin chiến thắng chúng tôi mới...      0
#
#      dataset_type
# 0           train
# 1           train
# 2           train
# 3           train
# ...

# %%
add_data['check'] = None
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\1617552413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data['check'] = None

# %%
new_data = pd.concat([train_data, add_data], ignore_index=True)

# %%
new_data.to_csv('expand_dataset\\train+viettan.csv', index=False)

# %%
new_data
# Out:
#            id                                               text  label  \
# 0           0                                    Bấp bênh vl thế      1
# 1           1  Chắc cũng biết ko tồn tại đc bao lâu nữa nên c...      1
# 2           2  Thấy chán ad page này kiến thức thì nông cản c...      1
# 3           3       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0
# 4           4  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1
# ...       ...                                                ...    ...
# 37796  104074  Người việt Nam bị đối sử như người Duy Ngô Nhĩ...      0
# 37797  104075                                    Top fan\nSáu Đô      0
# 37798  104076         30/4 3 que đu càng tụt quần bay trong gió😂      0
# 37799  104077        Hoan hô Việt Tân đưa tin rất hay và thời sự      0
# 37800  104078  Mời các bạn nghe tin chiến thắng chúng tôi mới...      0
#
#       dataset_type check
# 0            train  True
# 1            train   NaN
# ...

# %%
add_data2 = pd.read_csv('expand_dataset\\tgsb_crawl_comments_sim_label_predict.csv')

# %%
add_data2
# Out:
#                                                     text     label  \
# 0      Du Thiên tuyên bố: Hiếu Khổng Lồ sau Lệ cay 3 ...  0.000000
# 1      Ae hãy tin vào tôi😉Sau Lệ Cay 3 thì Hiếu Khổng...  0.618968
# 2                                          Bỏ đi a thiên  0.618968
# 3            Mình mới học võ được 1 tuần,mong thỉnh giáo  0.309484
# 4                                       Phuc Thien An Ho  0.000000
# ...                                                  ...       ...
# 32955  Thằng nhỏ nhắc khéo thôi mà làm gì đánh dữ vậy...  2.475873
# 32956  Sau 2 ngày mà vẫn còn nằm viện thì thương tích...  0.618968
# 32957             Như vậy là đủ chừa :))) k dám bênh nha  0.000000
# 32958                       Ngân Huỳnh tàn canh gió lạnh  1.237936
# 32959                           Cũng cái mỏ hại cái thân  1.547420
#
#        predict_prob  sim_label  predict_label
# 0          0.947269          0              1
# 1          0.008438          1              0
# ...

# %%
add_data2 = add_data2.loc[add_data2['sim_label'] == add_data2['predict_label']]

# %%
add_data2
# Out:
#                                                     text     label  \
# 3            Mình mới học võ được 1 tuần,mong thỉnh giáo  0.309484
# 9                  Vậy là chồng t chắc còn đang đi học .  0.000000
# 10     Minh Ngọc giờ chồng t ms đang năm 2 cứ bình tĩ...  0.000000
# 11                                      Hâhhah Lê Vân Hạ  0.309484
# 13                             Thanh Bình 96 2k2 đẹp đấy  0.000000
# ...                                                  ...       ...
# 32946               Trương Mỹ Dung nhìu chiện bị quánh à  1.237936
# 32950  K có văn hóa tại ai dạy… trách ai bh… trách bm...  1.856905
# 32951  Cái kết cho sự matday :))) thế là còn nhẹ cứ g...  0.618968
# 32953  Mấy đứa nhỏ cũng ít có láo. Nó béo nó gầy hay ...  2.475873
# 32957             Như vậy là đủ chừa :))) k dám bênh nha  0.000000
#
#        predict_prob  sim_label  predict_label
# 3          0.107540          0              0
# 9          0.001692          0              0
# ...

# %%
add_data2.reset_index(drop=False, inplace=True)
add_data2.rename(columns={'index': 'id'}, inplace=True)
add_data2['id'] = add_data2['id'] + start_index + len(add_data1)
add_data2['dataset_type'] = 'train'
add_data2['label'] = add_data2['predict_label']
add_data2['check'] = None
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\881570382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data2.rename(columns={'index': 'id'}, inplace=True)
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\881570382.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_data2['id'] = add_data2['id'] + start_index + len(add_data1)
# C:\Users\acer\AppData\Local\Temp\ipykernel_18332\881570382.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
add_data2
# Out:
#            id                                               text  label  \
# 0      104082        Mình mới học võ được 1 tuần,mong thỉnh giáo      0
# 1      104088              Vậy là chồng t chắc còn đang đi học .      0
# 2      104089  Minh Ngọc giờ chồng t ms đang năm 2 cứ bình tĩ...      0
# 3      104090                                   Hâhhah Lê Vân Hạ      0
# 4      104092                          Thanh Bình 96 2k2 đẹp đấy      0
# ...       ...                                                ...    ...
# 17176  137025               Trương Mỹ Dung nhìu chiện bị quánh à      1
# 17177  137029  K có văn hóa tại ai dạy… trách ai bh… trách bm...      1
# 17178  137030  Cái kết cho sự matday :))) thế là còn nhẹ cứ g...      1
# 17179  137032  Mấy đứa nhỏ cũng ít có láo. Nó béo nó gầy hay ...      1
# 17180  137036             Như vậy là đủ chừa :))) k dám bênh nha      0
#
#        predict_prob  sim_label  predict_label dataset_type check
# ...

# %%
add_data2 = add_data2[['id', 'text', 'label', 'dataset_type', 'check']]

# %%
add_data2
# Out:
#            id                                               text  label  \
# 0      104082        Mình mới học võ được 1 tuần,mong thỉnh giáo      0
# 1      104088              Vậy là chồng t chắc còn đang đi học .      0
# 2      104089  Minh Ngọc giờ chồng t ms đang năm 2 cứ bình tĩ...      0
# 3      104090                                   Hâhhah Lê Vân Hạ      0
# 4      104092                          Thanh Bình 96 2k2 đẹp đấy      0
# ...       ...                                                ...    ...
# 17176  137025               Trương Mỹ Dung nhìu chiện bị quánh à      1
# 17177  137029  K có văn hóa tại ai dạy… trách ai bh… trách bm...      1
# 17178  137030  Cái kết cho sự matday :))) thế là còn nhẹ cứ g...      1
# 17179  137032  Mấy đứa nhỏ cũng ít có láo. Nó béo nó gầy hay ...      1
# 17180  137036             Như vậy là đủ chừa :))) k dám bênh nha      0
#
#       dataset_type check
# 0            train  None
# 1            train  None
# ...

# %%
new_data = pd.concat([new_data, add_data2], ignore_index=True)

# %%
new_data
# Out:
#            id                                               text  label  \
# 0           0                                    Bấp bênh vl thế      1
# 1           1  Chắc cũng biết ko tồn tại đc bao lâu nữa nên c...      1
# 2           2  Thấy chán ad page này kiến thức thì nông cản c...      1
# 3           3       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0
# 4           4  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1
# ...       ...                                                ...    ...
# 54977  137025               Trương Mỹ Dung nhìu chiện bị quánh à      1
# 54978  137029  K có văn hóa tại ai dạy… trách ai bh… trách bm...      1
# 54979  137030  Cái kết cho sự matday :))) thế là còn nhẹ cứ g...      1
# 54980  137032  Mấy đứa nhỏ cũng ít có láo. Nó béo nó gầy hay ...      1
# 54981  137036             Như vậy là đủ chừa :))) k dám bênh nha      0
#
#       dataset_type check
# 0            train  True
# 1            train   NaN
# ...

# %%
new_data.to_csv('expand_dataset\\train.csv')
